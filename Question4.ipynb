# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Cleaned Data

# %%
google_play_df = pd.read_csv('data/googleplaystore-cleaned.csv')
google_play_reviews_df = pd.read_csv('data/googleplaystore_user_reviews-cleaned.csv')

# %% [markdown]
# # Question 4: In each category, how does number of installs depend on type?

# %%
google_play_df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
google_play_df['Installs_log'] = google_play_df['Installs_num'].apply(lambda x: np.log(x))

# %%
installs_by_category_type = google_play_df[['Category','Type','Installs_log']].groupby(['Category','Type']).median().reset_index()
sns.set_context('paper')
plt.figure(figsize = (10,10))
sns.barplot(x='Installs_log',y='Category', hue='Type', data=installs_by_category_type)
plt.title('Log Installs by Category and Type')
# Out:
# Text(0.5, 1.0, 'Log Installs by Category and Type')
