# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Load the Cleanned Data

# %%
google_play_df = pd.read_csv('data/googleplaystore-cleaned.csv')
google_play_reviews_df = pd.read_csv('data/googleplaystore_user_reviews-cleaned.csv')

# %% [markdown]
# # Question 2:
# Is there a relationship between ratings and size? How did you measure the relationship? Why did you choose this measurement?
#
# Please create a scatterplot of size vs ratings to demonstrate the relationship or lack thereof.

# %%
sns.scatterplot(x='Size', y='Rating', data=google_play_df)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Rating'>

# %% [markdown]
# ## Is there a relationship?
# Visual inspection indicates that there is at most a weak relationship between these variables. Below we compute the correlation between the variables to quantify this observation.

# %%
np.corrcoef(x = google_play_df['Size'], y= google_play_df['Rating'])
# Out:
# array([[nan, nan],
#        [nan,  1.]])
